# %% [markdown]
# #**Day 4 with Python**
# Support Vector Regression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MachineLearning/Day4/Position_Salaries.csv')

data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = data.iloc[:,1].values.reshape(-1,1)
Y = data.iloc[:,2].values

# %%
from sklearn.tree import DecisionTreeRegressor 
regressor = DecisionTreeRegressor(random_state = 0) 
regressor.fit(X, Y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = regressor.predict([[6.6]])
y_pred
# Out:
# array([200000.])

# %%
import matplotlib.pyplot as plt
import numpy as np


X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1)) 
plt.scatter(X, Y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid),'--', color = 'blue') 
plt.title('Salary to Level (Decision Tree Regression)') 
plt.xlabel('Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# The tree is finally exported and shown in the TREE STRUCTURE below, visualized using http://www.webgraphviz.com/ by copying the data from the ‘**tree.dot**’ file. You can open it using sublime text

# %%
# import export_graphviz
from sklearn.tree import export_graphviz

# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
export_graphviz(regressor, out_file ='/content/drive/MyDrive/Colab Notebooks/MachineLearning/Day4/tree.dot',
			feature_names =['Level'])
